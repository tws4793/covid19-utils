# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/out/figures.csv')
df['date'] = pd.to_datetime(df['date'])
df['rate_recovered'] = df['total_recovered'] / df['total_cases']
df
# Out:
#           date  new_community  new_dormitory  new_non_dormitory  new_imported  \
# 0   2020-01-23              0            NaN                NaN             1
# 1   2020-01-24              0            NaN                NaN             2
# 2   2020-01-25              0            NaN                NaN             0
# 3   2020-01-26              0            NaN                NaN             1
# 4   2020-01-27              0            NaN                NaN             1
# ..         ...            ...            ...                ...           ...
# 298 2020-11-16              0            0.0                NaN             5
# 299 2020-11-17              0            0.0                NaN             6
# 300 2020-11-18              0            0.0                NaN             5
# 301 2020-11-19              0            0.0                NaN             4
# 302 2020-11-20              0            0.0                NaN             4
#
# ...

# %%
df_latest = df.tail(1)
df_latest
# Out:
#           date  new_community  new_dormitory  new_non_dormitory  new_imported  \
# 302 2020-11-20              0            0.0                NaN             4
#
#      new_cases  new_recovered  new_deaths  correction  total_active  \
# 302          4              6           0           0            57
#
#      total_recovered  total_cases  total_deaths  total_icu  rate_recovered
# 302            58058        58143            28          1        0.998538

# %%
df_new = df_latest.copy()
df_new.index = np.arange(0, len(df_new))
df_new
# Out:
#         date  new_community  new_dormitory  new_non_dormitory  new_imported  \
# 0 2020-11-20              0            0.0                NaN             4
#
#    new_cases  new_recovered  new_deaths  correction  total_active  \
# 0          4              6           0           0            57
#
#    total_recovered  total_cases  total_deaths  total_icu  rate_recovered
# 0            58058        58143            28          1        0.998538

# %%
id(df), id(latest), id(new)
# Out:
# (140658447334704, 140658515756608, 140658514674448)

# %%
pd.DataFrame(df_new)
# Out:
#           date  new_community  new_dormitory  new_non_dormitory  new_imported  \
# 302 2020-11-20              0            0.0                NaN             4
#
#      new_cases  new_recovered  new_deaths  correction  total_active  \
# 302          4              6           0           0            57
#
#      total_recovered  total_cases  total_deaths  total_icu  rate_recovered
# 302            58058        58143            28          1        0.998538

# %%
from IPython.lib.security import passwd

passwd('com pee')
# Out:
# 'sha1:abc6169e7d89:4852adb8679b2d1c1af4a76f32da88eb6915a665'

# %%
assert type(1) != type(2)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-29-1b3b6f9492eb> in <module>
# ----> 1 assert type(1) != type(2)
#
# AssertionError:

# %%
isinstance(None, int)
# Out:
# False
